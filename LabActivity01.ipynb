# %%
import pandas as pd
import os
os.chdir('C:\\Users\\witze\\Downloads')
#for my directory issues
df = pd.read_csv('DS6021-Fall26-Anonymized.csv')

df.head()
df.info()
df.describe()

df['Have you ever used SQL?'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Timestamp                                                      86 non-null     str
#  1   What was your undergraduate major?                             86 non-null     str
#  2   What type of phone do you have?                                85 non-null     str
#  3   How many years ago did you receive your undergraduate degree?  86 non-null     str
#  4   How many hours do you sleep in a typical night?                86 non-null     str
#  5   Rate your proficiency with git/github                          86 non-null     int64
#  6   Rate your proficiency with Python                              86 non-null     int64
# ...

# %%
df['What type of phone do you have?'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df['Rate your proficiency with git/github'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df['Rate your proficiency with Python'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
pd.crosstab(df['Rate your proficiency with git/github'], df['Rate your proficiency with Python']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Rate your proficiency with git/github'>

# %%
pd.crosstab(df['Rate your proficiency with git/github'], df['Have you ever used SQL?']).plot(kind='bar')
# Out:
# <Axes: xlabel='Rate your proficiency with git/github'>

# %%
pd.crosstab(df['Rate your proficiency with Python'], df['Have you ever used SQL?']).plot(kind='bar')
# Out:
# <Axes: xlabel='Rate your proficiency with Python'>

# %% [markdown]
# For step 1, I wanted to clean several of the numeric columns, but the ranges given halted my ability to clean out all non-numeric characters without potentially adding serious outliers to each column. If I complete this data cleaning, I would've made the hours of sleep, states visited, and ideal temperature columns numeric.
#
# I wish I could've cleaned the data better. I'm not feeling well, so I did what I could with what I had. Nothing about the data I did visualize really surprised me.
# As for alternatives on cleaning the data, I could've went deeper into the numeric variables and eliminated all non-numeric characters, then cut out all outliers. I decided not to do this entirely because I don't have the time to figure out how to do this. I was also considering making the hours of sleep a categorical variable after cleaning, but again, I chose not to do this due to my illness and time constraints.
# In a business context, a potential outcome of cleaning my data with python is that I'd keep all my code in one place, where I can easily execute the same actions on a brand new dataset in front of clients to give them immediate results.
#
# My key finding was that there is a correlation between SQL use and self rated python proficiency. The same goes with that of SQL use and self rated Github proficiency. People who have SQL experience show a higher amount of confidence in python and Github. Another finding I found fascinating was the lack of android users. My initial assumption was that both iphone and android users had a similar amount of people in MSDS.
